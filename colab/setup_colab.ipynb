# %% [markdown]
# # LP Transformation — Colab Setup
#
# Clone the repo and run benchmarks on Colab's GPU.

# %%
# Clone the repo
# !git clone https://github.com/msprengholz/lp-transformation.git
# %cd lp-transformation

# %%
# Install dependencies
# !pip install -r requirements.txt
# !pip install numba  # for numba backend
# !pip install slangpy  # uncomment when slangpy is available

# %%
# Check GPU availability
# !nvidia-smi || echo 'No GPU detected'

# %%
# Run tests
# !python -m pytest tests/ -v --tb=short

# %%
# Run benchmarks
# !python -m benchmarks.benchmark_runner --solver all --n-layers 2,4,8,12,16,24 --samples 3
